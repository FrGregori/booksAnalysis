# %% [markdown]
# You have to work on the files:
# *  [Books](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Books.csv.gz)
# *  [Book ratings](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Book-Ratings.csv.gz)
# *  [Users](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Users.csv.gz)
# *  [Goodbooks books](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/goodbooks.csv.gz)
# *  [Goodbooks ratings](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/goodbooks-ratings.csv.gz)
#
# ### Notes
#
# 1.    It is mandatory to use GitHub for developing the project.
# 1.    The project must be a jupyter notebook.
# 1.    There is no restriction on the libraries that can be used, nor on the Python version.
# 1.    To read those files, you need to use the `encoding = 'latin-1'` option.
# 1.    All questions on the project **must** be asked in a public channel on [Zulip](https://focs.zulipchat.com), otherwise no  answer will be given.

# %% [markdown]
# ### Importing data

# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('Books.csv', sep=';', encoding='latin-1', low_memory=False)
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
book_ratings = pd.read_csv('Book-Ratings.csv', sep=';', encoding='latin-1')
book_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users = pd.read_csv('Users.csv', sep=';', encoding='latin-1')
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
good_books = pd.read_csv('goodbooks.csv', sep=',', encoding='latin-1')
good_books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
good_books_ratings = pd.read_csv('goodbooks-ratings.csv', sep=',', encoding='latin-1')
good_books_ratings.sort_values(by='book_id').head()
# Out:
#     user_id  book_id  rating
# 18        4        2       5
# 33        4        5       4
# 35        4        8       4
# 70        4       13       4
# 53        8       14       5

# %% [markdown]
# ### 1. Normalize the location field of *Users* dataset, splitting into city, region, country.

# %% [markdown]
# It is assumed that the field 'Location' is formatted as follows: city,region,country<br/>
# If the field contains less than two commas, the corresponding cell will be empty<br/>
# If the field contains more than two commas, the column 'Country' will contain all extra values, as no more info are provided

# %%
users[['City', 'Region', 'Country']] = users['Location'].str.split(',', 2, expand=True)
users
# Out:
#         User-ID                            Location   Age         City  \
# 0             1                  nyc, new york, usa   NaN          nyc
# 1             2           stockton, california, usa  18.0     stockton
# 2             3     moscow, yukon territory, russia   NaN       moscow
# 3             4           porto, v.n.gaia, portugal  17.0        porto
# 4             5  farnborough, hants, united kingdom   NaN  farnborough
# ...         ...                                 ...   ...          ...
# 278853   278854               portland, oregon, usa   NaN     portland
# 278854   278855  tacoma, washington, united kingdom  50.0       tacoma
# 278855   278856           brampton, ontario, canada   NaN     brampton
# 278856   278857           knoxville, tennessee, usa   NaN    knoxville
# 278857   278858                dublin, n/a, ireland   NaN       dublin
#
#                   Region          Country
# 0               new york              usa
# 1             california              usa
# 2        yukon territory           russia
# 3               v.n.gaia         portugal
# 4                  hants   united kingdom
# ...                  ...              ...
# 278853            oregon              usa
# 278854        washington   united kingdom
# 278855           ontario           canada
# 278856         tennessee              usa
# 278857               n/a          ireland
#
# [278858 rows x 6 columns]

# %% [markdown]
# Checking for empty cells in 'Region' or 'Country' column. It means that the field 'Location' contains zero or one comma. So there are some missing informations

# %%
users[(users['Region'].isna()) | (users['Country'].isna())]
# Out:
#         User-ID             Location   Age           City     Region Country
# 29419     29420  st. louis, missouri  68.0      st. louis   missouri    None
# 134376   134377        lawrenceville  30.0  lawrenceville       None    None

# %% [markdown]
# Checking for extra informations contained in 'Location' field (more than 2 commas in text). Extra informtions are collected in 'Country' column.

# %%
users[~(users['Country'].isna()) & (users['Country'].str.contains(','))]
# Out:
#         User-ID                                           Location   Age  \
# 435         436            ivanhoe, melbourne, victoria, australia  53.0
# 814         815       davis bay, sechelt, british columbia, canada  43.0
# 840         841                   saint charles, mo, missouri, usa  24.0
# 956         957            santiago, santiago,metropolitana, chile   NaN
# 1459       1460                mansoura, dakahlia, mansoura, egypt  34.0
# ...         ...                                                ...   ...
# 277717   277718          colorado springs, co 80901, colorado, usa  62.0
# 277753   277754                           north bend,, oregon, usa  60.0
# 278028   278029  mansfield, nottinghamshire, england, united ki...  31.0
# 278214   278215                   nelson, motueka, nz, new zealand  28.0
# 278808   278809          norfolk, england, england, united kingdom  49.0
#
#                     City            Region                    Country
# 435              ivanhoe         melbourne        victoria, australia
# 814            davis bay           sechelt   british columbia, canada
# 840        saint charles                mo              missouri, usa
# 956             santiago          santiago       metropolitana, chile
# 1459            mansoura          dakahlia            mansoura, egypt
# ...                  ...               ...                        ...
# 277717  colorado springs          co 80901              colorado, usa
# 277753        north bend                                  oregon, usa
# 278028         mansfield   nottinghamshire    england, united kingdom
# 278214            nelson           motueka            nz, new zealand
# 278808           norfolk           england    england, united kingdom
#
# [1508 rows x 6 columns]

# %% [markdown]
# ### 2. For each book in the *Books* dataset, compute its average rating.

# %% [markdown]
# A new column, 'Book-Rating', will be added to books dataFrame, containing the average rating. A left join opertion will be performed, in order to keep all the books contained in initial books dataset. Some books will have an empty 'Book-Rating'

# %%
len(books)
# Out:
# 271359

# %%
books = pd.merge(books, book_ratings.groupby('ISBN')['Book-Rating'].mean(), on = 'ISBN', how='left')

# %%
books.sort_values(by='ISBN').head()
# Out:
#               ISBN                                         Book-Title  \
# 254248  0000913154  The Way Things Work: An Illustrated Encycloped...
# 215806  0001010565                                    Mog's Christmas
# 42562   0001046438                                               Liar
# 112555  0001046713                       Twopence to Cross the Mersey
# 42604   000104687X  T.S. Eliot Reading \The Wasteland\" and Other ...
#
#                           Book-Author Year-Of-Publication  \
# 254248  C. van Amerongen (translator)                1967
# 215806                    Judith Kerr                1992
# 42562                     Stephen Fry                   0
# 112555                Helen Forrester                1992
# 42604                      T.S. Eliot                1993
#
#                        Publisher  \
# 254248      Simon &amp; Schuster
# 215806                   Collins
# 42562           Harpercollins Uk
# 112555  HarperCollins Publishers
# 42604   HarperCollins Publishers
#
#                                               Image-URL-S  \
# 254248  http://images.amazon.com/images/P/0000913154.0...
# 215806  http://images.amazon.com/images/P/0001010565.0...
# 42562   http://images.amazon.com/images/P/0001046438.0...
# 112555  http://images.amazon.com/images/P/0001046713.0...
# 42604   http://images.amazon.com/images/P/000104687X.0...
#
#                                               Image-URL-M  \
# 254248  http://images.amazon.com/images/P/0000913154.0...
# 215806  http://images.amazon.com/images/P/0001010565.0...
# 42562   http://images.amazon.com/images/P/0001046438.0...
# 112555  http://images.amazon.com/images/P/0001046713.0...
# 42604   http://images.amazon.com/images/P/000104687X.0...
#
#                                               Image-URL-L  Book-Rating
# 254248  http://images.amazon.com/images/P/0000913154.0...          8.0
# 215806  http://images.amazon.com/images/P/0001010565.0...          0.0
# 42562   http://images.amazon.com/images/P/0001046438.0...          9.0
# 112555  http://images.amazon.com/images/P/0001046713.0...          0.0
# 42604   http://images.amazon.com/images/P/000104687X.0...          6.0

# %%
books[books['Book-Rating'].isnull()]
# Out:
#               ISBN                                         Book-Title  \
# 1365    044990671X                                      Bronze Mirror
# 1367    0929587081                                   Men and Brethren
# 1368    155970117X                                 My Father, His Son
# 1369    0688105408             Starlings Laughing: A Memoir of Africa
# 3122    0671568485                           The STAR TREK THE RETURN
# ...            ...                                                ...
# 271340  1874166633  Introducing Nietzsche (Foundations in Children...
# 271341  0130897930                 Core Web Programming (2nd Edition)
# 271342  020130998X  The Unified Modeling Language Reference Manual...
# 271343  2268032019         Petite histoire de la dÃ?ÃÂ©sinformation
# 271346  3442150663                                        Der Mossad.
#
#                 Book-Author Year-Of-Publication                    Publisher  \
# 1365          Jeanne Larsen                1992             Ballantine Books
# 1367    James Gould Cozzens                1989          Elephant Paperbacks
# 1368         Reidar Jonsson                1991        Little Brown &amp; Co
# 1369     June Vendall Clark                1991                Harpercollins
# 3122        William Shatner                1996                   Audioworks
# ...                     ...                 ...                          ...
# 271340        Laurence Gane                1998            Natl Book Network
# 271341           Marty Hall                2001            Prentice Hall PTR
# 271342       James Rumbaugh                1998  Addison-Wesley Professional
# 271343     Vladimir Volkoff                1999           Editions du Rocher
# 271346     Victor Ostrovsky                2000                     Goldmann
#
#                                               Image-URL-S  \
# 1365    http://images.amazon.com/images/P/044990671X.0...
# 1367    http://images.amazon.com/images/P/0929587081.0...
# 1368    http://images.amazon.com/images/P/155970117X.0...
# 1369    http://images.amazon.com/images/P/0688105408.0...
# 3122    http://images.amazon.com/images/P/0671568485.0...
# ...                                                   ...
# 271340  http://images.amazon.com/images/P/1874166633.0...
# 271341  http://images.amazon.com/images/P/0130897930.0...
# 271342  http://images.amazon.com/images/P/020130998X.0...
# 271343  http://images.amazon.com/images/P/2268032019.0...
# 271346  http://images.amazon.com/images/P/3442150663.0...
#
#                                               Image-URL-M  \
# 1365    http://images.amazon.com/images/P/044990671X.0...
# 1367    http://images.amazon.com/images/P/0929587081.0...
# 1368    http://images.amazon.com/images/P/155970117X.0...
# 1369    http://images.amazon.com/images/P/0688105408.0...
# 3122    http://images.amazon.com/images/P/0671568485.0...
# ...                                                   ...
# 271340  http://images.amazon.com/images/P/1874166633.0...
# 271341  http://images.amazon.com/images/P/0130897930.0...
# 271342  http://images.amazon.com/images/P/020130998X.0...
# 271343  http://images.amazon.com/images/P/2268032019.0...
# 271346  http://images.amazon.com/images/P/3442150663.0...
#
#                                               Image-URL-L  Book-Rating
# 1365    http://images.amazon.com/images/P/044990671X.0...          NaN
# 1367    http://images.amazon.com/images/P/0929587081.0...          NaN
# 1368    http://images.amazon.com/images/P/155970117X.0...          NaN
# 1369    http://images.amazon.com/images/P/0688105408.0...          NaN
# 3122    http://images.amazon.com/images/P/0671568485.0...          NaN
# ...                                                   ...          ...
# 271340  http://images.amazon.com/images/P/1874166633.0...          NaN
# 271341  http://images.amazon.com/images/P/0130897930.0...          NaN
# 271342  http://images.amazon.com/images/P/020130998X.0...          NaN
# 271343  http://images.amazon.com/images/P/2268032019.0...          NaN
# 271346  http://images.amazon.com/images/P/3442150663.0...          NaN
#
# [1209 rows x 9 columns]

# %% [markdown]
# ### 3. For each book in the *GoodBooks* dataset, compute its average rating.

# %% [markdown]
# The average_rating column is already present. However, let's try to compute it on order to check if the result is the same

# %%
def calc_avg_ratings(row):
    return (row['ratings_1']*1 + row['ratings_2']*2 +row['ratings_3']*3 +row['ratings_4']*4 +row['ratings_5']*5)/row['work_ratings_count']
  
good_books['avg_rating'] = good_books.apply(calc_avg_ratings, axis=1)

# %%
good_books.sort_values(by='book_id')[['book_id', 'isbn', 'title', 'average_rating', 'avg_rating']].head()
# Out:
#    book_id       isbn                                              title  \
# 0        1  439023483            The Hunger Games (The Hunger Games, #1)
# 1        2  439554934  Harry Potter and the Sorcerer's Stone (Harry P...
# 2        3  316015849                            Twilight (Twilight, #1)
# 3        4   61120081                              To Kill a Mockingbird
# 4        5  743273567                                   The Great Gatsby
#
#    average_rating  avg_rating
# 0            4.34    4.341984
# 1            4.44    4.443047
# 2            3.57    3.571067
# 3            4.25    4.254818
# 4            3.89    3.887376

# %% [markdown]
# ### 4. Merge together all rows sharing the same book title, author and publisher. We will call the resulting datset `merged books`. The books that have not been merged together will not appear in `merged books`.

# %% [markdown]
# The books will be grouped by title, author, publisher into a new dataset, containing the grouping size too.
# Into the dataset there will be only records with size > 1

# %%
merged_books = books.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index = False).size()
merged_books = merged_books[merged_books['size'] > 1]

# %%
len(merged_books)
# Out:
# 4725

# %%
merged_books.head(20)
# Out:
#                                              Book-Title  \
# 41                            !%@ (A Nutshell handbook)
# 59    'A Hell of a Place to Lose a Cow': An American...
# 255   10,000 dreams interpreted: A dictionary of dreams
# 465                                    101 Famous Poems
# 713                  15 Houseplants Even You Can't Kill
# 725                                  158 POUND MARRIAGE
# 741                       1700: Scenes from London Life
# 783   1921 : The Great Novel of the Irish Civil War ...
# 964                          2001. Odyssee im Weltraum.
# 1001                                  2010: Odyssey Two
# 1015                                2061: Odyssey Three
# 1017                              2095 (Time Warp Trio)
# 1031                                    21 Sugar Street
# 1068                                               24/7
# 1102                                         2ND COMING
# 1109                                         2nd Chance
# 1161    30 Days to Experiencing Spiritual Breakthroughs
# 1174                                         30 Seconds
# 1291                             365 Ways to Cook Pasta
# 1334                                         3rd Degree
#
#                   Book-Author                       Publisher  size
# 41              Donnalyn Frey                        O'Reilly     2
# 59                Tim Brookes             National Geographic     2
# 255   Gustavus Hindman Miller       Barnes &amp; Nobles Books     2
# 465               Roy J. Cook  McGraw-Hill/Contemporary Books     3
# 713                 Joe Elder               Berkley Pub Group     2
# 725               John Irving                          Pocket     2
# 741            Maureen Waller        Four Walls Eight Windows     2
# 783           Morgan Llywelyn                     Forge Books     2
# 964          Arthur C. Clarke                           Heyne     2
# 1001         Arthur C. Clarke                   Del Rey Books     2
# 1015         Arthur C. Clarke                   Del Rey Books     2
# 1017             Jon Scieszka                    Puffin Books     2
# 1031              Lynn Lauber         W W Norton &amp; Co Inc     2
# 1068                Jim Brown                Ballantine Books     2
# 1102             Walker Percy                          Pocket     3
# 1109          James Patterson                   Little, Brown     2
# 1161          Bruce Wilkinson                       Multnomah     2
# 1174                      Sam                    Warner Books     2
# 1291            Marie Simmons        HarperCollins Publishers     2
# 1334          James Patterson          Time Warner Audiobooks     2

# %% [markdown]
# ### 5. For each book in `merged books` compute its average rating.
#
# The average is computed considering all books in `books` that have been merged.

# %%
merged_books_rating = pd.merge(books, merged_books, on=['Book-Title', 'Book-Author', 'Publisher'])[['Book-Title', 'Book-Author', 'Publisher', 'Book-Rating']]

# %%
merged_books_rating_groupby = merged_books_rating.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False)
merged_books_avg_rating = merged_books_rating_groupby.mean()
len(merged_books_avg_rating)
# Out:
# 4725

# %%
merged_books_avg_rating.head()
# Out:
#                                           Book-Title              Book-Author  \
# 0                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 1  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 2  10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller
# 3                                   101 Famous Poems              Roy J. Cook
# 4                 15 Houseplants Even You Can't Kill                Joe Elder
#
#                         Publisher  Book-Rating
# 0                        O'Reilly     3.000000
# 1             National Geographic     1.700000
# 2       Barnes &amp; Nobles Books     6.958333
# 3  McGraw-Hill/Contemporary Books     3.111111
# 4               Berkley Pub Group     0.000000

# %% [markdown]
# ### 6. For each book in `merged books` compute the minimum and maximum of the average ratings over all corresponding books in the `books` dataset.
#
# Hence for each book in `merged books` we will have exactly two values (a minimum and a maximum)

# %% [markdown]
# Using the previous groupBy object done on merged_books

# %%
merged_books_rating_groupby.agg({'Book-Rating': ['mean', 'min', 'max']})
# Out:
#                                              Book-Title  \
#
# 0                             !%@ (A Nutshell handbook)
# 1     'A Hell of a Place to Lose a Cow': An American...
# 2     10,000 dreams interpreted: A dictionary of dreams
# 3                                      101 Famous Poems
# 4                    15 Houseplants Even You Can't Kill
# ...                                                 ...
# 4720                                                Zia
# 4721                                                Zia
# 4722                                Zimmermann Telegram
# 4723  Zoids Chaotic Century (Zoids: Chaotic Century ...
# 4724         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
#
#                   Book-Author                       Publisher Book-Rating  \
#                                                                      mean
# 0               Donnalyn Frey                        O'Reilly    3.000000
# 1                 Tim Brookes             National Geographic    1.700000
# 2     Gustavus Hindman Miller       Barnes &amp; Nobles Books    6.958333
# 3                 Roy J. Cook  McGraw-Hill/Contemporary Books    3.111111
# 4                   Joe Elder               Berkley Pub Group    0.000000
# ...                       ...                             ...         ...
# 4720             Scott O'Dell               Laurel-Leaf Books    2.547619
# 4721             Scott O'Dell                  Yearling Books    1.000000
# 4722          Barbara Tuchman                Ballantine Books    2.000000
# 4723           Michiro Ueyama                      Viz Comics   10.000000
# 4724    RÃ?ÃÂ¼diger Nehberg                           Piper    3.833333
#
#
#             min        max
# 0      0.000000   6.000000
# 1      0.000000   3.400000
# 2      6.666667   7.250000
# 3      0.000000   5.000000
# 4      0.000000   0.000000
# ...         ...        ...
# 4720   1.666667   3.428571
# 4721   0.000000   2.000000
# 4722   0.000000   4.000000
# 4723  10.000000  10.000000
# 4724   2.666667   5.000000
#
# [4725 rows x 6 columns]

# %% [markdown]
# ### 7. For each book in `goodbooks`, compute the list of its authors. Assuming that the number of reviews with a text (column `work_text_reviews_count`) is split equally among all authors, find for each authors the total number of reviews with a text. We will call this quantity the *shared number of reviews with a text*.

# %% [markdown]
# Defining a function that computes author reviews for each row of good_books. For each author inserts a row in a different dataframe

# %%
authors = []

def computeAuthorReviews(row):
    auth_list = row['authors'].split(',')
    for i in auth_list:
        authors.append([row['book_id'], row['original_publication_year'], i, row['work_text_reviews_count']/len(auth_list)])
        
good_books.apply(computeAuthorReviews, 1)
good_books_authors = pd.DataFrame(authors, columns=['good_book_id', 'original_publication_year', 'author', 'shared_number_of_reviews_with_a_text'])
good_books_authors.head()
# Out:
#    good_book_id  original_publication_year           author  \
# 0             1                     2008.0  Suzanne Collins
# 1             2                     1997.0     J.K. Rowling
# 2             2                     1997.0   Mary GrandPrÃ©
# 3             3                     2005.0  Stephenie Meyer
# 4             4                     1960.0       Harper Lee
#
#    shared_number_of_reviews_with_a_text
# 0                              155254.0
# 1                               37933.5
# 2                               37933.5
# 3                               95009.0
# 4                               72586.0

# %%
good_books.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url', 'avg_rating'],
#       dtype='object')

# %% [markdown]
# ### 8. For each year of publication, determine the author that has the largest value of the shared number of reviews with a text.

# %% [markdown]
# Computing the maximum review value for each year

# %%
max_reviews_year = good_books_authors.groupby(['original_publication_year'], as_index = False)['shared_number_of_reviews_with_a_text'].max()

# %%
max_reviews_year.head(5)
# Out:
#    original_publication_year  shared_number_of_reviews_with_a_text
# 0                     -720.0                           1620.200000
# 1                     1595.0                           7389.000000
# 2                     1811.0                           3842.000000
# 3                     1813.0                          49152.000000
# 4                     1818.0                           6664.333333

# %% [markdown]
# There can be more than one author with the same max value of reviews. Using a for loop to find them

# %%
authors_top_reviews = pd.DataFrame([])
for ind in max_reviews_year.index:
    authors_top_reviews = authors_top_reviews.append(
            good_books_authors[(good_books_authors['original_publication_year'] == max_reviews_year['original_publication_year'][ind])
                                & (good_books_authors['shared_number_of_reviews_with_a_text'] == max_reviews_year['shared_number_of_reviews_with_a_text'][ind])
            ])

authors_top_reviews.head(15)
# Out:
#      good_book_id  original_publication_year                       author  \
# 104            79                     -720.0                        Homer
# 105            79                     -720.0                Robert Fagles
# 106            79                     -720.0                    E.V. Rieu
# 107            79                     -720.0            FrÃ©dÃ©ric Mugler
# 108            79                     -720.0                 Bernard Knox
# 41             29                     1595.0          William Shakespeare
# 42             29                     1595.0     Robert           Jackson
# 98             76                     1811.0                  Jane Austen
# 99             76                     1811.0                  Tony Tanner
# 100            76                     1811.0                Ros Ballaster
# 10             10                     1813.0                  Jane Austen
# 91             71                     1818.0  Mary Wollstonecraft Shelley
# 92             71                     1818.0         Percy Bysshe Shelley
# 93             71                     1818.0               Maurice Hindle
# 57             43                     1847.0            Charlotte BrontÃ«
#
#      shared_number_of_reviews_with_a_text
# 104                           1620.200000
# 105                           1620.200000
# 106                           1620.200000
# 107                           1620.200000
# 108                           1620.200000
# 41                            7389.000000
# 42                            7389.000000
# 98                            3842.000000
# 99                            3842.000000
# 100                           3842.000000
# 10                           49152.000000
# 91                            6664.333333
# 92                            6664.333333
# 93                            6664.333333
# 57                           15606.000000

# %% [markdown]
# ### 9. Assuming that there are no errors in the ISBN fields, find the books in both datasets, and compute the difference of average rating according to the ratings and the goodratings datasets

# %% [markdown]
# In books dataset the average rating is contained in column 'Book-Rating' and in good_books dataset the value is contained in 'average_rating' column

# %%
merged_books_1 = pd.merge(books[['ISBN', 'Book-Title', 'Book-Rating']], good_books[['isbn','average_rating']], left_on='ISBN', right_on='isbn')
merged_books_1['diff_avg'] = merged_books_1['Book-Rating'] - merged_books_1['average_rating']
merged_books_1
# Out:
#          ISBN                                         Book-Title  Book-Rating  \
# 0  1400032717  The Curious Incident of the Dog in the Night-T...     4.813187
# 1  014028009X                              Bridget Jones's Diary     3.751852
# 2  014038572X                      The Outsiders (Now in Speak!)     4.460674
# 3  1594480001                                    The Kite Runner     2.400000
# 4  043965548X  Harry Potter and the Prisoner of Azkaban (Harr...     3.533333
#
#          isbn  average_rating  diff_avg
# 0  1400032717            3.85  0.963187
# 1  014028009X            3.75  0.001852
# 2  014038572X            4.06  0.400674
# 3  1594480001            4.26 -1.860000
# 4  043965548X            4.53 -0.996667

# %% [markdown]
# ### 10. Split the users dataset according to the age. One dataset contains the users with unknown age, one with age 0-14, one with age 15-24, one with age 25-34, and so on.

# %% [markdown]
# Using a dictionary to insert the splitted rows of users dataset<br/>
# Inserting rows with unknown age<br/>
# Using a while loop in order to find the records of users dataset with 'Age' column into the correct range<br/>

# %%
usr_splitted = {}
index = 0
usr_splitted['unknown'] = users[users['Age'].isnull()]
while index < users['Age'].max():
    indexHigh = index + 15 if index == 0 else index + 10
    key = f'{index}-{indexHigh-1}'
    usr_splitted[key] = users[(users['Age'] >= index) & (users['Age'] < indexHigh)]
    index = indexHigh

for i in usr_splitted.keys():
    print(f'****** Users with age in range \'{i}\' are: {len(usr_splitted[i])} ******\n')
    print(usr_splitted[i][['User-ID', 'Age']].head(3))
    print('\n')
# Out:
# ****** Users with age in range 'unknown' are: 110762 ******
#
#    User-ID  Age
# 0        1  NaN
# 2        3  NaN
# 4        5  NaN
#
#
# ****** Users with age in range '0-14' are: 4313 ******
#
#     User-ID   Age
# 10       11  14.0
# 18       19  14.0
# 40       41  14.0
#
#
# ****** Users with age in range '15-24' are: 40001 ******
#
#     User-ID   Age
# 1         2  18.0
# 3         4  17.0
# 19       20  19.0
#
#
# ****** Users with age in range '25-34' are: 50767 ******
#
#     User-ID   Age
# 9        10  26.0
# 12       13  26.0
# 17       18  25.0
#
#
# ****** Users with age in range '35-44' are: 32690 ******
#
#     User-ID   Age
# 53       54  44.0
# 66       67  43.0
# 69       70  44.0
#
#
# ****** Users with age in range '45-54' are: 23152 ******
#
#     User-ID   Age
# 20       21  46.0
# 43       44  51.0
# 88       89  54.0
#
#
# ****** Users with age in range '55-64' are: 12493 ******
#
#     User-ID   Age
# 5         6  61.0
# 24       25  55.0
# 62       63  57.0
#
#
# ****** Users with age in range '65-74' are: 3596 ******
#
#      User-ID   Age
# 171      172  66.0
# 251      252  65.0
# 482      483  72.0
#
#
# ****** Users with age in range '75-84' are: 615 ******
#
#      User-ID   Age
# 220      221  79.0
# 689      690  80.0
# 957      958  78.0
#
#
# ****** Users with age in range '85-94' are: 83 ******
#
#        User-ID   Age
# 4346      4347  93.0
# 11389    11390  93.0
# 17375    17376  90.0
#
#
# ****** Users with age in range '95-104' are: 278 ******
#
#       User-ID    Age
# 1288     1289  103.0
# 1322     1323  104.0
# 3084     3085  104.0
#
#
# ****** Users with age in range '105-114' are: 20 ******
#
#        User-ID    Age
# 8329      8330  114.0
# 32655    32656  110.0
# 80532    80533  106.0
#
#
# ****** Users with age in range '115-124' are: 23 ******
#
#        User-ID    Age
# 3210      3211  119.0
# 17902    17903  123.0
# 27717    27718  123.0
#
#
# ****** Users with age in range '125-134' are: 5 ******
#
#        User-ID    Age
# 24410    24411  133.0
# 28090    28091  128.0
# 50768    50769  133.0
#
#
# ****** Users with age in range '135-144' are: 9 ******
#
#        User-ID    Age
# 30589    30590  141.0
# 46263    46264  141.0
# 71799    71800  136.0
#
#
# ****** Users with age in range '145-154' are: 11 ******
#
#        User-ID    Age
# 11325    11326  148.0
# 12691    12692  151.0
# 35860    35861  148.0
#
#
# ****** Users with age in range '155-164' are: 4 ******
#
#         User-ID    Age
# 61103     61104  162.0
# 63665     63666  156.0
# 126167   126168  159.0
#
#
# ****** Users with age in range '165-174' are: 2 ******
#
#         User-ID    Age
# 48098     48099  172.0
# 119281   119282  168.0
#
#
# ****** Users with age in range '175-184' are: 2 ******
#
#         User-ID    Age
# 45688     45689  175.0
# 183332   183333  183.0
#
#
# ****** Users with age in range '185-194' are: 2 ******
#
#         User-ID    Age
# 132667   132668  186.0
# 275582   275583  189.0
#
#
# ****** Users with age in range '195-204' are: 9 ******
#
#         User-ID    Age
# 13272     13273  201.0
# 102627   102628  199.0
# 160894   160895  200.0
#
#
# ****** Users with age in range '205-214' are: 8 ******
#
#        User-ID    Age
# 52471    52472  209.0
# 52648    52649  212.0
# 76864    76865  209.0
#
#
# ****** Users with age in range '215-224' are: 3 ******
#
#         User-ID    Age
# 37834     37835  219.0
# 211520   211521  223.0
# 245230   245231  220.0
#
#
# ****** Users with age in range '225-234' are: 7 ******
#
#         User-ID    Age
# 1578       1579  231.0
# 8457       8458  230.0
# 163826   163827  226.0
#
#
# ****** Users with age in range '235-244' are: 3 ******
#
#        User-ID    Age
# 8781      8782  239.0
# 20856    20857  244.0
# 58285    58286  237.0

# %% [markdown]
# ### 11. Find the books that appear only in the goodbooks datasets.

# %% [markdown]
# From good_books dataset removing records that appears in books dataset too, identified by ISBN

# %%
good_books[~good_books['isbn'].isin(books['ISBN'])]
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         1            2767052       2767052   2792775          272
# 1         2                  3             3   4640799          491
# 2         3              41865         41865   3212258          226
# 3         4               2657          2657   3275794          487
# 4         5               4671          4671    245494         1356
# ..      ...                ...           ...       ...          ...
# 94       95               5297          5297   1858012         2303
# 95       96           13536860      13536860  18034963          133
# 96       97              17245         17245   3165724         2207
# 97       98            5060378       5060378   6976108          209
# 98       99           11857408      11857408  16813814          147
#
#           isbn        isbn13                                    authors  \
# 0    439023483  9.780439e+12                            Suzanne Collins
# 1    439554934  9.780440e+12               J.K. Rowling, Mary GrandPrÃ©
# 2    316015849  9.780316e+12                            Stephenie Meyer
# 3     61120081  9.780061e+12                                 Harper Lee
# 4    743273567  9.780743e+12                        F. Scott Fitzgerald
# ..         ...           ...                                        ...
# 94   375751513  9.780376e+12             Oscar Wilde, Jeffrey Eugenides
# 95   345803507  9.780346e+12                                 E.L. James
# 96   393970124  9.780394e+12  Bram Stoker, Nina Auerbach, David J. Skal
# 97   307269981  9.780307e+12                 Stieg Larsson, Reg Keeland
# 98  1612130585  9.781612e+12                                 E.L. James
#
#     original_publication_year                            original_title  ...  \
# 0                      2008.0                          The Hunger Games  ...
# 1                      1997.0  Harry Potter and the Philosopher's Stone  ...
# 2                      2005.0                                  Twilight  ...
# 3                      1960.0                     To Kill a Mockingbird  ...
# 4                      1925.0                          The Great Gatsby  ...
# ..                        ...                                       ...  ...
# 94                     1891.0                The Picture of Dorian Gray  ...
# 95                     2012.0                        Fifty Shades Freed  ...
# 96                     1897.0                                   Dracula  ...
# 97                     2006.0               Flickan som lekte med elden  ...
# 98                     2011.0                       Fifty Shades Darker  ...
#
#    work_ratings_count work_text_reviews_count  ratings_1  ratings_2  \
# 0             4942365                  155254      66715     127936
# 1             4800065                   75867      75504     101676
# 2             3916824                   95009     456191     436802
# 3             3340896                   72586      60427     117415
# 4             2773745                   51992      86236     197621
# ..                ...                     ...        ...        ...
# 94             674551                   19647       9825      30735
# 95             610116                   25287      39079      55691
# 96             689739                   17263      11756      36719
# 97             649253                   31423       4623      15781
# 98             623340                   28052      37245      58935
#
#     ratings_3  ratings_4  ratings_5  \
# 0      560092    1481305    2706317
# 1      455024    1156318    3011543
# 2      793319     875073    1355439
# 3      446835    1001952    1714267
# 4      606158     936012     947718
# ..        ...        ...        ...
# 94     129420     246892     257679
# 95     109963     140304     265079
# 96     151396     246043     243825
# 97      91021     258236     279592
# 98     114203     150906     262051
#
#                                             image_url  \
# 0   https://images.gr-assets.com/books/1447303603m...
# 1   https://images.gr-assets.com/books/1474154022m...
# 2   https://images.gr-assets.com/books/1361039443m...
# 3   https://images.gr-assets.com/books/1361975680m...
# 4   https://images.gr-assets.com/books/1490528560m...
# ..                                                ...
# 94  https://images.gr-assets.com/books/1424596966m...
# 95  https://images.gr-assets.com/books/1336418837m...
# 96  https://images.gr-assets.com/books/1387151694m...
# 97  https://images.gr-assets.com/books/1351778881m...
# 98  https://images.gr-assets.com/books/1358266080m...
#
#                                       small_image_url  avg_rating
# 0   https://images.gr-assets.com/books/1447303603s...    4.341984
# 1   https://images.gr-assets.com/books/1474154022s...    4.443047
# 2   https://images.gr-assets.com/books/1361039443s...    3.571067
# 3   https://images.gr-assets.com/books/1361975680s...    4.254818
# 4   https://images.gr-assets.com/books/1490528560s...    3.887376
# ..                                                ...         ...
# 94  https://images.gr-assets.com/books/1424596966s...    4.055317
# 95  https://images.gr-assets.com/books/1336418837s...    3.879526
# 96  https://images.gr-assets.com/books/1387151694s...    3.976401
# 97  https://images.gr-assets.com/books/1351778881s...    4.220469
# 98  https://images.gr-assets.com/books/1358266080s...    3.868840
#
# [94 rows x 24 columns]

# %% [markdown]
# ### 12. Assuming that each pair (author, title) identifies a book, for each book find the number of times it appears in the books dataset. Which books appear the most times?

# %% [markdown]
# Grouping by title and author in order to find the number of ISBN having same title and author

# %%
books_count = books.groupby(['Book-Title', 'Book-Author'], as_index=False)['ISBN'].count()
books_count.rename(columns={'ISBN': 'Count'}, inplace=True)
books_count.head(3)
# Out:
#                                           Book-Title       Book-Author  Count
# 0   A Light in the Storm: The Civil War Diary of ...       Karen Hesse      1
# 1                              Always Have Popsicles    Rebecca Harvin      1
# 2               Apple Magic (The Collector's series)  Martina Boudreau      1

# %% [markdown]
# Finding the book that appears most times

# %%
books_count.iloc[books_count['Count'].idxmax()]
# Out:
# Book-Title          Little Women
# Book-Author    Louisa May Alcott
# Count                         21
# Name: 113850, dtype: object

# %% [markdown]
# There can be more than one row having max count. Checking it

# %%
books_count[books_count['Count'] == books_count['Count'].max()]
# Out:
#           Book-Title        Book-Author  Count
# 113850  Little Women  Louisa May Alcott     21

# %% [markdown]
# ### 13. Find the author with the highest average rating according to the goodbooks datasets.

# %% [markdown]
# Finding the record having max on average_rating

# %%
max_index = good_books['average_rating'].idxmax()
good_books.iloc[max_index][['authors', 'average_rating']]
# Out:
# authors           J.K. Rowling, Mary GrandPrÃ©
# average_rating                            4.61
# Name: 24, dtype: object

# %% [markdown]
# Checking if there are only one maximum value or if there are more than one record that have the same max value

# %%
good_books[good_books['average_rating'] == good_books.iloc[max_index]['average_rating']][['authors', 'average_rating']]
# Out:
#                          authors  average_rating
# 24  J.K. Rowling, Mary GrandPrÃ©            4.61
